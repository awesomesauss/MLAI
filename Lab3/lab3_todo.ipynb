# %% [markdown]
# # Lab 3: Functions, Modules and OOP
#
# This notebook uses `student.py` and the file handler classes.
# Complete the TODO sections in the `.py` files, then run the cells below.

# %% [markdown]
# ## Part 1: Function in student.py
# Complete `unixtime_date(input)` so it converts a Unix timestamp into `YYYY-MM-DD HH:MM:SS`.

# %%
import time
import student

current_ts = int(time.time())
print('Current Unix timestamp:', current_ts)
print('Readable date:', student.unixtime_date(current_ts))
# Out:
# Current Unix timestamp: 1778552681
# Readable date: 2026-05-12 10:24:41

# %% [markdown]
# ## Part 2: OOP with Parent and Child Classes
# - `FileHandler` is the parent class.
# - `JsonFile`, `CsvFile`, and `LogFile` are child classes.
# - Child classes inherit `filesize()` and implement `read()`.

# %%
from JsonFile import JsonFile
from CsvFile import CsvFile
from LogFile import LogFile

print('JSON read:', JsonFile('sample.json').read())
print('CSV read:', CsvFile('sample.csv').read())
print('LOG read:', LogFile('sample.log').read())
# Out:
# JSON read: {'module': 'Python Lab 3', 'topic': 'Functions, modules and OOP', 'students': 24}
# CSV read: [['name', 'score'], ['Alice', '85'], ['Ben', '90'], ['Cara', '88']]
# LOG read: ['2026-03-18 10:23:45 [Error] Failed to connect to server', '2026-03-18 10:25:12 [Error] Timeout while reading response']

# %% [markdown]
# ## Part 3: Command Line Test
# Run these commands in a terminal after completing the TODOs:
#
# ```bash
# python3 FileHandler.py sample.json
# python3 FileHandler.py sample.csv
# python3 FileHandler.py sample.log
# ```

# %% [markdown]
# ## Reflection Questions
# 1. Why do all child classes have a `read()` method?
# 2. What method is inherited from the parent class?
# 3. Why is regex useful for the `.log` file?
